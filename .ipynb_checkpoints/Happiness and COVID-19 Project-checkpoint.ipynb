# %% [markdown]
# Amy Zhou
#
# DH 140
#
# Professor Winjum
#
# March 24, 2023

# %% [markdown]
# # World Happiness and COVID-19 Pandemic: How Do We Feel?

# %% [markdown]
# # Introduction

# %% [markdown]
# The COVID-19 pandemic upended the lives of nearly every person across the globe. With  mandated goverment shelter-in-places, contested vaccination policies, and overwhelmed medical systems and professionals, 2019-2021 was a challenging time for all countries. Mental health professionals reported record levels of depression and anxiety. To understand the root of discontent, a broad analysis across countries during the pandemic years will be conducted to pinpoint trends, factors, and correlations between world happiness and COVID-19 pandemic severity. The findings are to be used to create a better response to the next global pandemic.
#
# ### Datasets:
# * *World Happiness Reports for 2019-2021* from [World Happiness Report Archive](https://worldhappiness.report/archive/), Uploaded to [GitHub](https://github.com/amywzhou/DH140/tree/main/Happiness%20Data)
#
# * *Covid Statistics for 2019-2021* via [CORGIs datasets](https://corgis-edu.github.io/corgis/datasets/csv/covid/covid.csv)
#
# ### Dataset Descriptions:
# *World Happiness Reports for 2019-2021* includes happiness rank for each country, as well as the values for each factor that affects the happpiness rank. The World Happiness Reports obtains their data from happiness surveys sent out by the Gallup Group.
# *Covid Statistics for 2019-2020* includes COVID-19 case statistics by country between December 2019 and December 2020. The data was collected by the Epidemic INtelligence team of the European Center for Disease Control and Prevention (ECDC).
#
# ### Motivation:
# To analyze how world happiness shifts during a pandemic.
# To identify what factors are most impacted during a pandemic.
# To assess how pandemic severity impacts countries' happiness.
#
# Overall, to provide guidance on how to navigate a response to the next global pandemic.
#
# ### Research Questions:
# > How has happiness by country shifted between 2019-2021, the time frame of the COVID-19 pandemic? Which countries had the greatest positive and negative shifts in happiness?
#
# > How did happiness factors shift and affect happiness scores between 2019-2021?
#
# > Is there a correlation between happiness score and COVID-19 severity?

# %% [markdown]
# ### Necessary Packages:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import folium
import requests

# %% [markdown]
# # Methods/Data Exploration
# This section includes, for each dataset:
#
# * First few rows of data, information, and statistics for each dataset.
# * One data visualization per dataset to explore initial trends and understand dataset contents.
# * Data cleaning, standardization, merging, and consolidation

# %% [markdown]
# #### Import Datasets

# %%
#2019 World Happiness Report
whr19 = pd.read_csv('https://raw.githubusercontent.com/amywzhou/DH140/main/Happiness%20Data/2019.csv')

#2020 World Happiness Report
whr20 = pd.read_csv('https://raw.githubusercontent.com/amywzhou/DH140/main/Happiness%20Data/2020.csv')

#2021 World Happiness Report
whr21 = pd.read_csv('https://raw.githubusercontent.com/amywzhou/DH140/main/Happiness%20Data/2021.csv')

# %%
#Covid Cases by Country, 12/2019 - 12/2020
covid = pd.read_csv("https://corgis-edu.github.io/corgis/datasets/csv/covid/covid.csv")

# %% [markdown]
# ### Covid Data

# %%
covid.head() #first few rows of data
# Out:
#    Date.Day  Date.Month  Date.Year  Data.Cases  Data.Deaths Location.Country  \
# 0        31          12       2019           0            0      Afghanistan
# 1        31          12       2019           0            0          Algeria
# 2        31          12       2019           0            0          Armenia
# 3        31          12       2019           0            0        Australia
# 4        31          12       2019           0            0          Austria
#
#   Location.Code  Data.Population Location.Continent  Data.Rate
# 0           AFG         38041757               Asia        0.0
# 1           DZA         43053054             Africa        0.0
# 2           ARM          2957728             Europe        0.0
# 3           AUS         25203200            Oceania        0.0
# 4           AUT          8858775             Europe        0.0

# %%
covid.info() #information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53629 entries, 0 to 53628
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date.Day            53629 non-null  int64
#  1   Date.Month          53629 non-null  int64
#  2   Date.Year           53629 non-null  int64
#  3   Data.Cases          53629 non-null  int64
#  4   Data.Deaths         53629 non-null  int64
#  5   Location.Country    53629 non-null  object
#  6   Location.Code       53545 non-null  object
#  7   Data.Population     53629 non-null  int64
#  8   Location.Continent  53629 non-null  object
#  9   Data.Rate           53629 non-null  float64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 4.1+ MB

# %%
covid.describe() #dataset statistics
# Out:
#            Date.Day    Date.Month     Date.Year     Data.Cases   Data.Deaths  \
# count  53629.000000  53629.000000  53629.000000   53629.000000  53629.000000
# mean      15.845009      6.406776   2019.998751     898.374033     22.873035
# std        8.940220      2.600373      0.035324    5019.868017    124.259355
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      4.000000   2020.000000       0.000000      0.000000
# 50%       16.000000      7.000000   2020.000000      13.000000      0.000000
# 75%       24.000000      9.000000   2020.000000     206.000000      3.000000
# max       31.000000     12.000000   2020.000000  102507.000000   4928.000000
#
#        Data.Population     Data.Rate
# count     5.362900e+04  53629.000000
# mean      4.164579e+07     44.382863
# std       1.548019e+08    113.147610
# min      -1.000000e+00   -147.419587
# 25%       1.324820e+06      0.269203
# 50%       7.813207e+06      4.652782
# ...

# %% [markdown]
# From the above statistics, there are some nonsensical data points. In particular, having a negative population, number of cases, and number of deaths does not make sense. Thus, it is necessary to replace nonsensical values with "NaN" instead.
#
# Additionally, the dataset is missing statistics of cumulative covid cases adjusted for population. In order to analyze the severity of the COVID-19 pandemic per country, we normalize the data to represent COVID cases per capita.

# %%
covid.loc[covid['Data.Population'] < 0, 'Data.Population'] = np.nan
covid.loc[covid['Data.Cases'] < 0, 'Data.Cases'] = np.nan
covid.loc[covid['Data.Deaths'] < 0, 'Data.Deaths'] = np.nan

annual_covid = covid.groupby('Location.Country')['Data.Cases'].sum()
population = covid.groupby('Location.Country')['Data.Population'].max()
per_capita = (annual_covid / population) * 1000000

per_capita = per_capita.rename('Per capita')
covid = covid.merge(per_capita, on='Location.Country')

covid['Per capita'].describe()
# Out:
# count    53545.000000
# mean      9479.093736
# std      11462.588429
# min          3.347534
# 25%        832.691685
# 50%       5503.594314
# 75%      13352.000470
# max      66227.338961
# Name: Per capita, dtype: float64

# %% [markdown]
# To visualize what the cases per capita look like per country, a horizonal bar chart is helpful. The countries with the greatest cases per capita will appear on top, and the countries with the least cases per capita will appear on the bottom.

# %%
per_capita = per_capita.sort_values(ascending=True)
per_capita.plot(kind='barh', figsize=(18, 36))
plt.xlabel('Cases per Capita')
plt.ylabel('Country')
plt.title('Cases per Capita by Country')
plt.show()

# %% [markdown]
# ### 2019 - World Happiness Data

# %%
whr19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
whr19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# The columns do not appear to add up overall score. Cross-referencing the 2019 World Happiness Report, the missing factor contributing to the happiness score is Dystopia and residual. An additional column is added to the whr19 dataframe to account for Dystopia and Residual, in order to have a complete dataset for data visualization.

# %%
whr19['Dystopia + residual'] = whr19['Score'] - whr19[['GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices','Generosity', 'Perceptions of corruption']].sum(axis=1)

# %%
whr19.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# A good way to understand the data stored within WHR19 is to create a segmented bar chart for each country, where each bar shows the breakdown of their happiness ladder score. The bar chart is effective at displaying the range of ladder scores and the contributions of each happiness factor toward scores.

# %%
happiness_bar = whr19.groupby('Country or region')[['GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices','Generosity', 'Perceptions of corruption','Dystopia + residual']].sum()
happiness_bar = happiness_bar.loc[happiness_bar.sum(axis=1).sort_values(ascending=True).index]

happiness_bar.plot(kind='barh', stacked=True, figsize=(18, 36))
plt.xlabel('Value')
plt.ylabel('Country')
plt.title('Happiness Score Breakdown By Country')
plt.show()

# %% [markdown]
# ### 2020 - World Happiness Data
#
# Repeat the same data exploration steps as above.

# %%
whr20.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
whr20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
# ...

# %%
whr20.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count     153.00000                      153.000000    153.000000
# mean        5.47324                        0.053538      5.578175
# std         1.11227                        0.018183      1.096823
# min         2.56690                        0.025902      2.628270
# 25%         4.72410                        0.040698      4.826248
# 50%         5.51500                        0.050606      5.607728
# 75%         6.22850                        0.060677      6.363886
# max         7.80870                        0.120590      7.869766
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    153.000000             153.000000      153.000000
# mean       5.368304               9.295706        0.808721
# std        1.128631               1.201588        0.121453
# min        2.505530               6.492642        0.319460
# 25%        4.603149               8.350645        0.737217
# ...

# %%
happiness_bar = whr20.groupby('Country name')[['Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices','Explained by: Generosity', 'Explained by: Perceptions of corruption', 'Dystopia + residual']].sum()
happiness_bar = happiness_bar.loc[happiness_bar.sum(axis=1).sort_values(ascending=True).index]

happiness_bar.plot(kind='barh', stacked=True, figsize=(18, 36))
plt.xlabel('Value')
plt.ylabel('Country')
plt.title('Happiness Score Breakdown By Country')
plt.show()

# %% [markdown]
# ### 2021 - World Happiness Data

# %%
whr21.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
whr21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
whr21.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
happiness_bar = whr21.groupby('Country name')[['Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices','Explained by: Generosity', 'Explained by: Perceptions of corruption', 'Dystopia + residual']].sum()
happiness_bar = happiness_bar.loc[happiness_bar.sum(axis=1).sort_values(ascending=True).index]

happiness_bar.plot(kind='barh', stacked=True, figsize=(18, 36))
plt.xlabel('Value')
plt.ylabel('Country')
plt.title('Happiness Score Breakdown By Country')
plt.show()

# %% [markdown]
# ### World Happiness Reports: Data Cleaning, Standardization, and Consolidation
#
# The world happiness datasets for 2019-2021 vary in what data is presented. The 2019 dataset is particularly different from the 2020 and 2021 datasets, as it only contains the data processed to show each factor's direct contribution to the happiness score. In the 2020 and 2021 datasets, direct contributions as well as raw data is shown. Furthermore, across all 3 datasets, the number of countries for which data is available varies, meaning there may be some countries that are represented in 2019 but not 2020, and so on.
#
# For some forms of analysis, it is beneficial to consolidate all three dataframes into one dataframe. In order to create a dataframe containing consistent information that can be easily grouped, columns and entries must be named in the same manner.

# %%
whr19 = whr19.rename(columns={'Country or region':'Country name',
                             'Score':'Ladder score',
                             'GDP per capita': 'Explained by: Log GDP per capita',
                             'Social support':'Explained by: Social support',
                             'Healthy life expectancy':'Explained by: Healthy life expectancy',
                             'Freedom to make life choices':'Explained by: Freedom to make life choices',
                             'Generosity':'Explained by: Generosity',
                             'Perceptions of corruption':'Explained by: Perceptions of corruption'})

# %% [markdown]
# Country names, in particular, must be renamed in a fashion that is consistent across all three dataframes. There must be an agreed-upon spelling/name of each country. Since one of the research questions inquires about geographical trends, a sensible country-naming model to use would be the folium country list since the package is likely to be used in analysis later.

# %%
#Obtain the folium list of country names 
response = requests.get('https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/world-countries.json')
folium_data = response.json()

folium_names = set()
for feature in folium_data['features']:
    folium_names.add(feature['properties']['name'])
    
print (folium_names)
# Out:
# {'Republic of the Congo', 'Somalia', 'Uruguay', 'Lesotho', 'Fiji', 'Rwanda', 'Turkmenistan', 'Mali', 'United Kingdom', 'Taiwan', 'Benin', 'Papua New Guinea', 'Kenya', 'Guinea', 'Laos', 'Lithuania', 'Israel', 'Mongolia', 'Jamaica', 'Syria', 'Costa Rica', 'Bolivia', 'Netherlands', 'Falkland Islands', 'Niger', 'Myanmar', 'Afghanistan', 'Colombia', 'Iran', 'Belarus', 'Guatemala', 'Ireland', 'Canada', 'Turkey', 'West Bank', 'Nigeria', 'Iceland', 'Haiti', 'Bhutan', 'Sierra Leone', 'Thailand', 'Czech Republic', 'Greenland', 'Albania', 'Burkina Faso', 'Libya', 'Bosnia and Herzegovina', 'Oman', 'Jordan', 'United Arab Emirates', 'Denmark', 'Kosovo', 'Swaziland', 'Burundi', 'Sweden', 'Venezuela', 'North Korea', 'Portugal', 'Switzerland', 'Guinea Bissau', 'South Korea', 'New Zealand', 'Togo', 'Gambia', 'Iraq', 'Belize', 'Slovenia', 'El Salvador', 'Latvia', 'Mozambique', 'Trinidad and Tobago', 'Uganda', 'Norway', 'Estonia', 'Qatar', 'Chile', 'Algeria', 'Madagascar', 'Yemen', 'Mexico', 'Peru', 'Fr
# ...

# %%
#Identify which countries to rename in each dataframe

folium_19 = set(whr19['Country name'].unique())-folium_names
folium_20 = set(whr20['Country name'].unique())-folium_names
folium_21 = set(whr21['Country name'].unique())-folium_names

print(folium_19)
print(folium_20)
print(folium_21)
# Out:
# {'Comoros', 'Serbia', 'Congo (Kinshasa)', 'Trinidad & Tobago', 'Palestinian Territories', 'Malta', 'Mauritius', 'Bahrain', 'Tanzania', 'United States', 'Hong Kong', 'Singapore', 'North Macedonia', 'Congo (Brazzaville)'}
# {'North Cyprus', 'Serbia', 'Comoros', 'Hong Kong S.A.R. of China', 'Congo (Kinshasa)', 'Palestinian Territories', 'Malta', 'Mauritius', 'Maldives', 'Bahrain', 'Tanzania', 'United States', 'Singapore', 'Taiwan Province of China', 'Congo (Brazzaville)'}
# {'North Cyprus', 'Serbia', 'Comoros', 'Hong Kong S.A.R. of China', 'Palestinian Territories', 'Malta', 'Mauritius', 'Maldives', 'Bahrain', 'Tanzania', 'United States', 'Singapore', 'Taiwan Province of China', 'North Macedonia', 'Congo (Brazzaville)'}

# %%
#Rename appropriately

whr19['Country name'] = whr19['Country name'].replace({
    'Trinidad & Tobago': 'Trinidad and Tobago', 
    'United States': 'United States of America', 
    'Serbia': 'Republic of Serbia', 
    'North Macedonia': 'Macedonia', 
    'Tanzania': 'United Republic of Tanzania',  
    'Congo (Brazzaville)': 'Republic of the Congo', 
    'Palestinian Territories': 'West Bank', 
    'Congo (Kinshasa)': 'Democratic Republic of the Congo'})

whr20['Country name'] = whr20['Country name'].replace({
    'United States': 'United States of America',
    'North Cyprus': 'Northern Cyprus',
    'Taiwan Province of China': 'Taiwan',
    'Serbia': 'Republic of Serbia',
    'Hong Kong S.A.R. of China': 'Hong Kong',
    'Tanzania': 'United Republic of Tanzania',
    'Congo (Brazzaville)': 'Republic of the Congo',
    'Palestinian Territories': 'West Bank',
    'Congo (Kinshasa)': 'Democratic Republic of the Congo'})

whr21['Country name'] = whr21['Country name'].replace({
    'United States': 'United States of America', 
    'North Cyprus': 'Northern Cyprus',
    'Taiwan Province of China': 'Taiwan', 
    'Serbia': 'Republic of Serbia', 
    'North Macedonia': 'Macedonia', 
    'Hong Kong S.A.R. of China': 'Hong Kong', 
    'Tanzania': 'United Republic of Tanzania', 
    'Congo (Brazzaville)': 'Republic of the Congo', 
    'Palestinian Territories': 'West Bank'})

# %% [markdown]
# Now all the countries are referred to similarly, and match the naming convention used in the folium geodata that will likely be used in analysis later on. Note that not all countries or territories are listed in the folium geodata. Regardless, the naming convention for those countries were still homogenized to one spelling.

# %% [markdown]
# Consistent country naming allows for dataframes to be merged by country name properly. Merging two consecutive year WHR datasets provides a dataframe that can be used easily to analyze data specific to each country per year interval, which is helpful for answering research questions analyzing change over time.

# %%
whr19_20 = whr19.merge(whr20, on='Country name', suffixes=('_19', '_20'))
whr20_21 = whr20.merge(whr21, on='Country name', suffixes=('_20', '_21'))

whr19_20.sample()
# Out:
#      Overall rank Country name  Ladder score_19  \
# 106           109     Cambodia              4.7
#
#      Explained by: Log GDP per capita_19  Explained by: Social support_19  \
# 106                                0.574                            1.122
#
#      Explained by: Healthy life expectancy_19  \
# 106                                     0.637
#
#      Explained by: Freedom to make life choices_19  \
# 106                                          0.609
#
#      Explained by: Generosity_19  Explained by: Perceptions of corruption_19  \
# 106                        0.232                                       0.062
#
#      Dystopia + residual_19  ... Generosity  Perceptions of corruption  \
# 106                   1.464  ...   0.051911                   0.822769
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita_20  \
# 106                  1.972317                             0.544635
#
#      Explained by: Social support_20  \
# ...

# %% [markdown]
# Merging 3 dataframes can be messy and lead to complications for some data visualizations, so concatenating the 3 world happiness can be helpful. To do so, a column containing information about the year of the data is added. Columns that are not present in all 3 dataframes are dropped as the data is not very helpful when absent across some rows. A single dataframe with three years' of WHR data is especially helpful for plotting 3-year average values.

# %%
whr19['Year']= 2019
whr20['Year']= 2020
whr21['Year']= 2021

whr19_short = whr19.drop(whr19.columns[0], axis=1)
whr20_short = whr20.drop(whr20.columns[[1] + list(range(3, 13))], axis=1)
whr21_short = whr21.drop(whr21.columns[[1] + list(range(3, 13))], axis=1)

# %%
whr_all = pd.concat([whr19_short, whr20_short, whr21_short])
whr_all.sample()
# Out:
#    Country name  Ladder score  Explained by: Log GDP per capita  \
# 94       Bhutan         5.082                             0.813
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 94                         1.321                                  0.604
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 94                                       0.457                      0.37
#
#     Explained by: Perceptions of corruption  Dystopia + residual  Year
# 94                                    0.167                 1.35  2019

# %% [markdown]
# ### COVID-19 Dataset: Data Cleaning, Standardization, and Consolidation
#
# In order to use the COVID-19 data in conjunction with the WHR data, especially when plotting data by country, it is important that the COVID dataset uses the same country naming convention as the WHRs. Again, the country naming will be set to the folium geodata standard, since it was used as the standard in all three WHR dataframes.

# %%
folium_covid = set(covid['Location.Country'].unique())-folium_names
print(folium_covid)
# Out:
# {'Saint_Vincent_and_the_Grenadines', 'Sri_Lanka', 'Brunei_Darussalam', 'San_Marino', 'Gibraltar', 'Czechia', 'Congo', 'Sint_Maarten', 'Maldives', 'United_Kingdom', 'Aruba', 'Palestine', 'United_Republic_of_Tanzania', 'Cape_Verde', 'Anguilla', 'Costa_Rica', 'Seychelles', 'Singapore', 'Holy_See', 'Sao_Tome_and_Principe', 'New_Zealand', 'Liechtenstein', 'Puerto_Rico', 'Jersey', 'Guinea_Bissau', 'South_Korea', 'Dominican_Republic', 'Barbados', 'Saint_Kitts_and_Nevis', 'Monaco', 'Western_Sahara', 'Timor_Leste', 'United_Arab_Emirates', 'Equatorial_Guinea', 'Saudi_Arabia', 'Cases_on_an_international_conveyance_Japan', 'Bahrain', 'Dominica', 'Malta', 'Bahamas', 'Turks_and_Caicos_islands', 'Bonaire, Saint Eustatius and Saba', 'Guam', 'Guernsey', 'Bermuda', 'Isle_of_Man', 'United_States_Virgin_Islands', 'Montserrat', 'Northern_Mariana_Islands', 'French_Polynesia', 'Papua_New_Guinea', 'Saint_Lucia', 'Central_African_Republic', 'United_States_of_America', 'Eswatini', 'Andorra', 'Grenada', 'Faroe
# ...

# %% [markdown]
# Most of the name discrepancies appear to be caused by the underscore between multiple-word country names. To reduce the number of one-on-one replacements, eliminate the underscores and do replacements on what is left.

# %%
covid['Location.Country'] = covid['Location.Country'].replace('_', ' ', regex=True)
folium_covid = set(covid['Location.Country'].unique())-folium_names
print(folium_covid)
# Out:
# {'Liechtenstein', 'British Virgin Islands', 'Sao Tome and Principe', 'Wallis and Futuna', 'Dominica', 'Cayman Islands', 'Turks and Caicos islands', 'Malta', 'Andorra', 'Grenada', 'Jersey', 'Cases on an international conveyance Japan', 'Gibraltar', 'Saint Lucia', 'Bahamas', 'Brunei Darussalam', 'Marshall Islands', 'Bonaire, Saint Eustatius and Saba', 'Guam', 'Czechia', 'Congo', 'Guernsey', 'Mauritius', 'Barbados', 'Maldives', 'Bermuda', 'Cote dIvoire', 'Monaco', 'Northern Mariana Islands', 'Faroe Islands', 'Aruba', 'Serbia', 'United States Virgin Islands', 'Montserrat', 'Palestine', 'Sint Maarten', 'Timor Leste', 'San Marino', 'Saint Vincent and the Grenadines', 'French Polynesia', 'Anguilla', 'Curasao', 'Comoros', 'Holy See', 'Falkland Islands (Malvinas)', 'Seychelles', 'Cape Verde', 'Bahrain', 'Saint Kitts and Nevis', 'Singapore', 'Isle of Man', 'Antigua and Barbuda', 'Eswatini', 'North Macedonia'}

# %%
covid['Location.Country'] = covid['Location.Country'].replace({
    'Czechia': 'Czech Republic',
    'Timor Leste': 'East Timor',
    'Falkland Islands (Malvinas)': 'Falkland Islands',
    'Cote dIvoire': 'Ivory Coast',
    'United Republic of Tanzania':'United Republic of Tanzania',
    'Palestine': 'West Bank',
    'Bahamas':'The Bahamas',
    'Brunei Darussalam': 'Brunei',
    'Congo':'Republic of the Congo',
    'North Macedonia':'Macedonia',
    'Serbia':'Republic of Serbia'
    })

folium_covid = set(covid['Location.Country'].unique())-folium_names
print(folium_covid)
# Out:
# {'Liechtenstein', 'British Virgin Islands', 'Sao Tome and Principe', 'Wallis and Futuna', 'Dominica', 'Cayman Islands', 'Turks and Caicos islands', 'Malta', 'Andorra', 'Grenada', 'Jersey', 'Cases on an international conveyance Japan', 'Gibraltar', 'Saint Lucia', 'Marshall Islands', 'Bonaire, Saint Eustatius and Saba', 'Guam', 'Guernsey', 'Mauritius', 'Barbados', 'Maldives', 'Bermuda', 'Monaco', 'Northern Mariana Islands', 'Faroe Islands', 'Aruba', 'United States Virgin Islands', 'Montserrat', 'Sint Maarten', 'San Marino', 'Saint Vincent and the Grenadines', 'French Polynesia', 'Anguilla', 'Curasao', 'Comoros', 'Holy See', 'Seychelles', 'Cape Verde', 'Bahrain', 'Saint Kitts and Nevis', 'Singapore', 'Isle of Man', 'Antigua and Barbuda', 'Eswatini'}

# %% [markdown]
# The remaining countries are not listed in the folium geodata. However, it is still important to check that they are consistently named with other countries in the WRH datasets that also are not in the folium database. After a manual comparison between the excess countries for COVID and the WHRs, it is evident that there are no duplicate countries that are spelled/named differently. Thus, the COVID dataframe is ready to be merged with the WHR datasets by country name. The merged dataframe will be as a helpful resource when analyzing the relationship between COVID severity and happiness scores.

# %%
covid = covid.rename(columns= {'Location.Country': 'Country name'})
covid_and_happiness = pd.merge(whr_all, covid, on='Country name')

covid_and_happiness.sample()
# Out:
#       Country name  Ladder score  Explained by: Log GDP per capita  \
# 77584        Ghana         5.088                              0.68
#
#        Explained by: Social support  Explained by: Healthy life expectancy  \
# 77584                         0.595                                  0.287
#
#        Explained by: Freedom to make life choices  Explained by: Generosity  \
# 77584                                       0.517                     0.268
#
#        Explained by: Perceptions of corruption  Dystopia + residual  Year  \
# 77584                                    0.058                2.684  2021
#
#        Date.Day  Date.Month  Date.Year  Data.Cases  Data.Deaths Location.Code  \
# 77584         5          10       2020        26.0          0.0           GHA
#
#        Data.Population Location.Continent  Data.Rate   Per capita
# 77584       30417858.0             Africa   2.712223  1599.159283

# %% [markdown]
# # Results/Analysis

# %% [markdown]
# ### Question 1:
# #### How has happiness shifted between 2019-2021, the time frame of the COVID-19 pandemic? Which countries had the greatest positive and negative shifts in happiness?

# %% [markdown]
# Boxplots of the happiness ladder score can be used to analyze general shifts in happiness. A general decrease in happiness could be represented by a lower mean; a general increase in happiness could be represented by a higher mean.

# %%
plt.boxplot([whr19['Ladder score'], whr20['Ladder score'], whr21['Ladder score']], labels = ['2019', '2020', '2021'])
plt.title('Happiness Scores Between 2019-2021')
plt.xlabel('Year')
plt.ylabel('Happiness Score')

plt.show()

# %%
whr19['Ladder score'].describe()
# Out:
# count    156.000000
# mean       5.407096
# std        1.113120
# min        2.853000
# 25%        4.544500
# 50%        5.379500
# 75%        6.184500
# max        7.769000
# Name: Ladder score, dtype: float64

# %%
whr20['Ladder score'].describe()
# Out:
# count    153.00000
# mean       5.47324
# std        1.11227
# min        2.56690
# 25%        4.72410
# 50%        5.51500
# 75%        6.22850
# max        7.80870
# Name: Ladder score, dtype: float64

# %%
whr21['Ladder score'].describe()
# Out:
# count    149.000000
# mean       5.532839
# std        1.073924
# min        2.523000
# 25%        4.852000
# 50%        5.534000
# 75%        6.255000
# max        7.842000
# Name: Ladder score, dtype: float64

# %% [markdown]
# According to the statistics and data descriptions, the mean and max happiness scores appear to increase each year. However, the lowest happiness scores are smaller as well. This means that between 2019-2021, some countries increased their happiness scores while others decreased their happiness scores.

# %% [markdown]
# The results do not strongly indicate that happiness increased or decreased during the pandemic and it is not possible to distinguish how many countries became more happy, remained neutral, or grew less happy. To calculate change per country, the happiness scores between two consecutive years are subtracted.The merged dataframe between two years ensures that the same two countries are being compared year to year.

# %%
happiness_diff = whr19_20['Ladder score_19'] - whr19_20['Ladder score_20']

plt.figure(figsize=(18, 40))
plt.barh(whr19_20['Country name'], happiness_diff)
plt.xlabel('Difference in Ladder score')
plt.ylabel('Country name')
plt.title('Change in Ladder score between 2019 and 2020')
# Out:
# Text(0.5, 1.0, 'Change in Ladder score between 2019 and 2020')

# %%
happiness_diff.describe()
# Out:
# count    152.000000
# mean      -0.054520
# std        0.183817
# min       -0.582900
# 25%       -0.154600
# 50%       -0.062700
# 75%        0.036250
# max        0.636100
# dtype: float64

# %% [markdown]
# Between 2019 and 2020, the mean change in happiness is negative, which indicates that general countries became less happy. The most positive change in happiness is 0.63, which corresponds to Afghanistan on the horizontal bar chart. Afghanistan therefore was the country that gained the most happiness between 2019 and 2020. The most negative change in happiness is -0.58, which corresponds to Liberia on the horizontal bar chart. Liberia therefore was the country that lost the most happiness between 2019 and 2020.

# %%
happiness_diff = whr20_21['Ladder score_20'] - whr20_21['Ladder score_21']

plt.figure(figsize=(18, 40))
plt.barh(whr20_21['Country name'], happiness_diff)
plt.xlabel('Difference in Ladder score')
plt.ylabel('Country name')
plt.title('Change in Ladder score between 2019 and 2020')
# Out:
# Text(0.5, 1.0, 'Change in Ladder score between 2019 and 2020')

# %%
happiness_diff.describe()
# Out:
# count    149.000000
# mean      -0.025387
# std        0.151797
# min       -0.606200
# 25%       -0.094100
# 50%       -0.011400
# 75%        0.052300
# max        0.759300
# dtype: float64

# %% [markdown]
# Between 2020 and 2021, the mean change in happiness is negative, which indicates that generally countries became less happy. The most positive change in happiness is 0.76, which corresponds to Pakistan on the horizontal bar chart. Pakistan therefore was the country that gained the most happiness between 2020 and 2021. The most negative change in happiness is -0.61, which corresponds to Armenia on the horizontal bar chart. Armenia therefore was the country that lost the most happiness between 2020 and 2021.

# %% [markdown]
# ### Question 2:
# #### How did happiness factors shift and affect happiness scores between 2019-2021?

# %% [markdown]
# To investigate how shifting happiness factors impact happiness scores, insight is needed regarding the relationship between each factor  and the happiness score.

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 10)) 

for i, col in enumerate(['Explained by: Log GDP per capita', 'Explained by: Social support',
                         'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices',
                         'Explained by: Generosity', 'Explained by: Perceptions of corruption']):
    row = i // 3  
    column = i % 3   
    
    x = whr_all.groupby('Country name')[col].mean()
    y = whr_all.groupby('Country name')['Ladder score'].mean()
    axs[row][column].scatter(x, y)  
    
    m, b = np.polyfit(x, y, 1)
    axs[row][column].plot(x, m * x + b, color='red')
        
    axs[row][column].set_xlabel(col)
    axs[row][column].set_ylabel('Ladder score')

plt.show()

# %% [markdown]
# The factors GDP per capita, Social support, healthy life expectancy, and freedom to make life decisions have a general direct relationship with happiness ladder; it appears that these four factors are play a critical role in determining happiness score such that a higher value in any of those factors are correlated with a higher overall happiness score. On the other hand, generosity and perception of corruption do not appear to have a clear relationship; higher values do not necessarily indicate a higher happiness score.
#
# Thus, understanding how GDP per capita, Social support, healthy life expectancy, and freedom to make life decisions have shifted between 2019-2021 is key to understanding how happiness scores have changed through the pandemic.

# %%
plt.boxplot([whr19['Explained by: Log GDP per capita'], whr20['Explained by: Log GDP per capita'], whr21['Explained by: Log GDP per capita']], labels = ['2019', '2020', '2021'])
plt.title('Log GDP per capita Contribution Between 2019-2021')
plt.xlabel('Year')
plt.ylabel('Log GDP per Capita Contribution')
plt.show()

# %% [markdown]
# The contributing factor of GDP per Capita decreased in 2020 before increasing in 2021. The 2021 values are higher than the 2019 values. Based on the relationship between GDP contribution and happiness score, the decreased GDP in 2020 likely lowered the average happiness score of 2020 while the increased GDP in 2021 likely raised the average happiness score of 2021.
#
# The decreased GDP in 2020 may be explained by local economies suffering during government mandated lock-downs in response to the COVID-19 pandemic. Many were not able to leave their homes and were laid off, so it is likely that people only bought the bare necessities. In 2021, many businesses began operating as normal again, likely causing an increase in GDP.

# %%
plt.boxplot([whr19['Explained by: Social support'], whr20['Explained by: Social support'], whr21['Explained by: Social support']], labels = ['2019', '2020', '2021'])
plt.title('Social support Contribution to Happiness Score Between 2019-2021')
plt.xlabel('Year')
plt.ylabel('Social support Contribution to Happiness Score')

plt.show()

# %% [markdown]
# The contributing factor of Social Support decreased every year from 2019-2021. Based on the relationship between social support and happiness score, the decreasing contribution of social support likely lowered the average happiness score of 2020 and 2021.
#
# The decreased social support contribution values coincide with themes of social distancing and weariness toward interacting with strangers during the pandemic. It would be reasonable for the social support factor to decrease due to lowered interactions with the community in general.

# %%
plt.boxplot([whr19['Explained by: Healthy life expectancy'], whr20['Explained by: Healthy life expectancy'], whr21['Explained by: Healthy life expectancy']], labels = ['2019', '2020', '2021'])
plt.title('Healthy life expectancy Contribution to Happiness Score Between 2019-2021')
plt.xlabel('Year')
plt.ylabel('Healthy life expectancy Contribution')

plt.show()

# %% [markdown]
# The contributing factor of healthy life expectancy decreased every year from 2019-2021. Based on the relationship between healthy life expectancy and happiness score, the decreasing contribution of social support likely lowered the average happiness score of 2020 and 2021.
#
# The decrease in healthy life expectancy may be explained by the high death rates from COVID-19. A majority of cases during the pandemic occurred during 2020, which may be a reason for the major decrease in healthy life expectancy in 2021.

# %%
plt.boxplot([whr19['Explained by: Freedom to make life choices'], whr20['Explained by: Freedom to make life choices'], whr21['Explained by: Freedom to make life choices']], labels = ['2019', '2020', '2021'])
plt.title('Freedom to make life choices Contribution to Happiness Score Between 2019-2021')
plt.xlabel('Year')
plt.ylabel('Freedom to make life choices Contribution ')
plt.show()

# %% [markdown]
# The contributing factor of freedom to make life choices increased every year from 2019-2021. Based on the relationship between freedom to make life choices and happiness score, the increasing contribution of social support likely raised the average happiness score of 2020 and 2021.
#
# The increased sense of freedom to make life choices is a surprising trend as the many governments mandated lock-downs and vaccinations during the pandemic, which was often perceived as an overreach of power. There is a possibility that the freedom to make life choices may have increased due to increased flexibility in work culture, although the freedom is only applicable to certain groups within the work force.

# %% [markdown]
# ### Question 3:
# #### Is there a correlation between COVID-19 pandemic severity and happiness score?

# %% [markdown]
# Some countries experienced larger COVID case volumes per capita than others. It is expected that countries with more cases per capita have a lower happiness due to the impact of COVID on the happiness factors.
#
# First, COVID severity and happiness scores by country can be visualized using a map. The toggles on the side allow the user to chose what to view. If a country has a dark ladder score color but a light COVID case per capita cover, it indicates a high happiness factor for a low case per capita count.

# %%
score_data = whr_all.groupby('Country name')['Ladder score'].mean()
covid_per_capita = covid.groupby('Country name')['Per capita'].mean()

m = folium.Map(location=[0, 0], zoom_start=1)

# Happiness Data
folium.Choropleth(
    geo_data="https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/world-countries.json",
    data=score_data,
    key_on="feature.properties.name",
    fill_color="BuPu",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Ladder score",
    name="Ladder Score",
).add_to(m)

# Covid Data
folium.Choropleth(
    geo_data="https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/world-countries.json",
    data=covid_per_capita, 
    key_on="feature.properties.name",
    fill_color="YlOrRd", 
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Annual COVID-19 Cases per Million People", 
    highlight=True,
    name="Annual COVID-19 Cases per Million People",
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Some countries, such as Canada, indicate low COVID cases per capita and a high happiness score, However, it is difficult to discern a trend from the visual.
#
# To analyze whether the relationship between COVID cases per capita and happiness score, a scattergraph can be plotted to visualize correlation.

# %%
per_cap = covid_and_happiness.groupby('Country name')['Per capita'].mean()
happ_avg = covid_and_happiness.groupby('Country name')['Ladder score'].mean()

m,b = np.polyfit(per_cap, happ_avg, 1) 

# plot scatter graph and approximation
plt.scatter(per_cap, happ_avg)
plt.plot(per_cap, m * per_cap + b, color='r')
plt.xlabel('COVID Per capita')
plt.ylabel('Ladder score')
plt.show()

# calculate R-squared
SS_res = np.sum((happ_avg - (m * per_cap + b)) ** 2) 
SS_tot = np.sum((happ_avg - np.mean(happ_avg)) ** 2) 
r2 = 1 - (SS_res / SS_tot)

print('R-squared:', r2)
# Out:
# R-squared: 0.24433827262928454

# %% [markdown]
# The R-squared value is relatively low and close to zero, indicating weak linear correlation between covid cases and happiness score. The scattergraph data also does not appear to follow any other polynomial fit. Thus, no conclusion can be drawn about COVID-case severity and happiness score at this time.

# %% [markdown]
# # Discussion

# %% [markdown]
# ## Findings
#
# To conclude, the findings from the data analysis are as follows:
#
#  ***How has happiness by country shifted between 2019-2021, the time frame of the COVID-19 pandemic? Which countries had the greatest positive and negative shifts in happiness?***
#
# The max happiness score between 2019-21 appears to increase very slightly each year. The mean and minimum happiness score betwen 2019-21 appears to decrease each year. However, the number of countries that increased or decreased in happiness nor the extent of each country's shift in happiness can be determined by examining the mean, max, and minimum happiness scores.
#
# Between 2019-20, Afghanistan had the greatest positive shift in happiness while Liberia had the most negative shift in happiness. Between 2020-21, Pakistan had the greatest positive shift in happiness while Armenia had the most negative shift in happiness.
#
# ***How did happiness factors shift and affect happiness scores between 2019-2021?***
#
# The factors GDP per capita, Social support, healthy life expectancy, and freedom to make life decisions appear to have a direct relationship with the happiness score such that an high value in any of the four factors usually indicates a higher-level happiness score. Generosity and perception of corruption do not appear to have a clear relationship with happiness scores such that high values in either factors did not necessarily correlate with high  happiness scores. Thus, the shifts in generosity and perception of corruption were not examined for their impacts on the happiness scores between 2019-21.
#
# | Contributing Factor        | 2019-20 Trend + Impact          | 2019-20 Trend + Impact  | Potential Causes   |
# | ------------- |:-------------:|:-------------:| -----:|
# | GDP per Capita     | Decreased Contribution; Decreased Happiness Score | Increased Contribution; Increased Happiness Score | Closing and Reopening local economies due to shelter in place mandates
# |  Social Support      | Decreased Contribution; Decreased Happiness Score |   Decreased Contribution; Decreased Happiness Score | Social distancing and shelter in place mandates
# |  Healthy Life Expectancy  | Decreased Contribution; Decreased Happiness Score| Decreased Contribution; Decreased Happiness Score | COVID-19 Deaths at all ages
# |  Freedom in Life Choices | Increased Contribution; Increased Happiness Score| Increased Contribution; Increased Happiness Score | Workplace flexibility|
#
# ***Is there a correlation between happiness score and COVID-19 severity?***
#
# The scattergraph of Covid Cases per Capita vs Happiness Score does not have a linear fit, as evidenced by a low R-squared value. There may be other correlations, but the scattergraph does not appear to follow any polynomial fits at this time.
#
# ## Importance
#
# The findings are valuable in a variety of ways. Happiness should be one of the top priorties of every government; understanding how pandemics impact happiness factors is critical for creating action plans for the next pandemic that may hit. For example, the major decrease in social support during the pandemic must be addressed: how might countries upkeep a social network for citizens when they must stay socially distanced?
#
# The findings reveal that case per capita severity is not a sole indicator of country happiness. It is possible for countries with low case counts to be on the lower end of the happiness spectrum, and it is possible for countries with high case counts to be on the higher end of the happiness spectrum. The lack of correlation suggests that country happiness during a pandemic may depend on other factors, such as country response and support systems in place.
#
# Understanding the factors of happiness and their changes during the pandemic is also valuable for mental health professionals. During the pandemic, numerous studies reported a plunge in mental health and an overwhelmed mental health indsutry.  By being aware of what may be the root of many clients' problems, mental health specialists are better able to address the issues and suggest preventative or resolutionary measures.
#
# ## Future Analysis and Considerations

# %% [markdown]
# It is important to note that the results of this study are limited. A potential source of error includes inconsistent country participation in world happiness surveys. Due to the pandemic, survey response collection was hindered in some countries. This may lead to a skew toward results from countries that are faring better than average. Future studies may opt to eliminate data from countries not present in all three survey years between 2019-21 to reduce error. Additionally, data for COVID cases could be sourced from a larger time range; the data readily available and used in this analysis only covers the range of 12/2019-12/2020.
#
# While conducting this data analysis, it became evident that there are many factors that can tie into the results. A wholistic and multi-faceted study is necessary to fully assess the dynamic of happiness scores during a pandemic. Government response to pandemics, medical ability and accessibillity per country, and cultural differences in evaluating happiness are just a few additional factors that could be considered.
